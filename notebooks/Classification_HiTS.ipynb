# %% [markdown]
# # Classification of HiTS

# %%
import sys
import os
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from astropy.table import Table
from metric_tools import *
from sklearn.externals import joblib
from statsmodels.robust import mad
from matplotlib.ticker import MaxNLocator

# %matplotlib inline
sns.set(style="white", color_codes=True, context="poster", font_scale=1)
#sns.set(style="ticks", color_codes=True, context="poster")
#sns.set_style({"xtick.direction": "in","ytick.direction": "in"})

mainpath = '/Users/jorgetil/Astro/HITS'

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
import astropy
print astropy.__version__
import sklearn
print sklearn.__version__
# Out:
# 2.0.6
# 0.17.1

# %%
matrix = np.array([[0.96, 0.04], [0.01, 0.99]])
save_path = '%s/figures/conf_matrix_per_nonper_RFC_new.pdf' % (mainpath)
labels = ['Nonperiodic', 'Periodic']

matrix = np.array([[1.00, 0.00], [0.02, 0.98]])
str_mtx = [['1.00', '0.00'], ['0.02', '0.98']]
save_path = '%s/figures/conf_matrix_var_nonvar_RFC_orgTS_new.pdf' % (mainpath)
labels = ['Nonvariable', 'Variable']

matrix = np.array([[0.97,0.01,0.01,0.01],
                   [0.02,0.92,0.05,0.01],
                   [0.02,0.04,0.94,0.00],
                   [0.01,0.04,0.03,0.93]])
str_mtx = np.array([['0.97','0.01','0.01','0.01'],
                   ['0.02','0.92','0.05','0.01'],
                   ['0.02','0.04','0.94','0.00'],
                   ['0.01','0.04','0.03','0.93']])
save_path = '%s/figures/conf_matrix_per_subcls_RFC_new.pdf' % (mainpath)
labels = ['DSCT', 'EB', 'RotVar','RRLYR']

fig, ax = plt.subplots(figsize=(9,7.8))
cax = ax.imshow(matrix, cmap='GnBu', aspect='auto')
cbar = fig.colorbar(cax, ticks=[0.2,0.4,0.6,0.8], fraction=0.046)
cbar.outline.set_visible(False)
ax.set_xlabel('Predicted Label', fontsize=17)
ax.set_ylabel('True Label', fontsize=17)
plt.xticks([0, 1, 2, 3], labels)
plt.yticks([-0.2, .9, 1.7, 2.7], labels, rotation='vertical')
ax.tick_params(axis='both', which='major', pad=8)
for i in range(len(matrix[0])):
    for j in range(len(matrix[1])):
        if matrix[i,j] < .5: 
            c = 'k'
        else:
            c= 'w'
        text = ax.text(j, i, str_mtx[i][j],
                        ha="center",
                        va="center",
                        color=c,
                        fontsize='medium')
for edge, spine in ax.spines.items():
        spine.set_visible(False)

plt.savefig(save_path , format='pdf', dpi=600, bbox_inches='tight')

plt.show()

# %% [markdown]
# ##### Summary of numbers for HiTS catalogs

# %% [markdown]
# ### Total detections:

# %% [markdown]
# * 2015: detection catalog with ~15 millions objects
#     * ~1.9 millions of lightcurves with >= 15 data points
#     * 2918 items with labels for variability obtaind from cross-match with SDSS, VSX, CSS, GCVS, RR-Lyrae from Medina et al. and Supernovae from HiTS, plus visual inspection of non-variables (within survey sensitivity), plus transfer from MACHO and active learning.

# %% [markdown]
# ### LC examples

# %% [raw]
# Non Periodic                                            | Periodic
#  :------------------------:|:---------------------------:
# <img src="lc_examples_nonP.png" style="width: 500px;"/> | <img src="lc_examples_P.png" style="width: 500px;"/>

# %% [markdown]
# ## FATS features

# %% [markdown]
# * Feature analysis for time series python package with more than 60 features.
# * Period estimation from Lomb-Scargle (implemented in FATS), Generalized Lomb-Scargle (gatspy) and Correntropy Kernel Periodogram (P4J)
# * Color indexes from g,r and i bands

# %% [markdown]
# ## Data set

# %% [raw]
# table_file = '%s/tables/Blind15A_full_features.csv'\
#               %(mainpath)
# full_ds = pd.read_csv(table_file)
# full_ds = full_ds.set_index('internalID')
# print full_ds.info()

# %% [raw]
# some_feat = ['Mean','Std','Meanvariance','Amplitude','Eta_e','Skew','StetsonK','PeriodGLS']
# g = sb.PairGrid(full_ds.sample(10000), vars=some_feat)
# g = g.map_diag(plt.hist)
# g = g.map_offdiag(plt.scatter)

# %% [markdown]
# ## Training set

# %%
table_file = '%s/tables/Blind14A_U_Blind15A_only_labeled.csv'\
              %(mainpath)
label_samp = pd.read_csv(table_file)
label_samp = label_samp.set_index('internalID')
print label_samp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8921 entries, Blind15A_35_N23_1408_3473 to Blind14A_40_S31_0322_2893
# Data columns (total 74 columns):
# ID                                 8921 non-null object
# raMedian                           8921 non-null float64
# decMedian                          8921 non-null float64
# X                                  8921 non-null float64
# Y                                  8921 non-null float64
# spCl                               3812 non-null object
# spSubCl                            2735 non-null object
# Var_Type                           8921 non-null object
# Var_subType                        256 non-null object
# Amplitude                          8921 non-null float64
# AndersonDarling                    8921 non-null float64
# Autocor_length                     8921 non-null float64
# Beyond1Std                         8921 non-null float64
# CAR_mean                           8921 non-null float64
# CAR_sigma                          8921 non-null float64
# CAR_tau                            8921 non-null float64
# Con                                8921 non-null float64
# Eta_e                              8921 non-null float64
# FluxPercentileRatioMid20           8921 non-null float64
# FluxPercentileRatioMid35           8921 non-null float64
# FluxPercentileRatioMid50           8921 non-null float64
# FluxPercentileRatioMid65           8921 non-null float64
# FluxPercentileRatioMid80           8921 non-null float64
# Freq1_harmonics_amplitude_0        8921 non-null float64
# Freq1_harmonics_amplitude_1        8921 non-null float64
# Freq1_harmonics_amplitude_2        8921 non-null float64
# Freq1_harmonics_amplitude_3        8921 non-null float64
# Freq1_harmonics_rel_phase_0        8921 non-null float64
# Freq1_harmonics_rel_phase_1        8921 non-null float64
# Freq1_harmonics_rel_phase_2        8921 non-null float64
# Freq1_harmonics_rel_phase_3        8921 non-null float64
# Freq2_harmonics_amplitude_0        8921 non-null float64
# Freq2_harmonics_amplitude_1        8921 non-null float64
# Freq2_harmonics_amplitude_2        8921 non-null float64
# Freq2_harmonics_amplitude_3        8921 non-null float64
# Freq2_harmonics_rel_phase_0        8921 non-null float64
# Freq2_harmonics_rel_phase_1        8921 non-null float64
# Freq2_harmonics_rel_phase_2        8921 non-null float64
# Freq2_harmonics_rel_phase_3        8921 non-null float64
# Freq3_harmonics_amplitude_0        8921 non-null float64
# Freq3_harmonics_amplitude_1        8921 non-null float64
# Freq3_harmonics_amplitude_2        8921 non-null float64
# Freq3_harmonics_amplitude_3        8921 non-null float64
# Freq3_harmonics_rel_phase_0        8921 non-null float64
# Freq3_harmonics_rel_phase_1        8921 non-null float64
# Freq3_harmonics_rel_phase_2        8921 non-null float64
# Freq3_harmonics_rel_phase_3        8921 non-null float64
# Gskew                              8921 non-null float64
# LinearTrend                        8921 non-null float64
# MaxSlope                           8921 non-null float64
# Mean                               8921 non-null float64
# Meanvariance                       8921 non-null float64
# MedianAbsDev                       8921 non-null float64
# MedianBRP                          8921 non-null float64
# PairSlopeTrend                     8921 non-null float64
# PercentAmplitude                   8921 non-null float64
# PercentDifferenceFluxPercentile    8921 non-null float64
# PeriodGLS                          8921 non-null float64
# PeriodLS                           8921 non-null float64
# PeriodWMCC                         8921 non-null float64
# Period_fit                         8921 non-null float64
# Psi_CS                             8921 non-null float64
# Psi_eta                            8921 non-null float64
# Q31                                8921 non-null float64
# Rcs                                8921 non-null float64
# Skew                               8921 non-null float64
# SlottedA_length                    8921 non-null float64
# SmallKurtosis                      8921 non-null float64
# Std                                8921 non-null float64
# StetsonK                           8921 non-null float64
# StetsonK_AC                        8921 non-null float64
# g-i                                2083 non-null float64
# g-r                                2540 non-null float64
# r-i                                2060 non-null float64
# dtypes: float64(69), object(5)
# memory usage: 5.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 8921 entries, Blind15A_35_N23_1408_3473 to Blind14A_40_S31_0322_2893
# Data columns (total 74 columns):
# ID                                 8921 non-null object
# raMedian                           8921 non-null float64
# decMedian                          8921 non-null float64
# X                                  8921 non-null float64
# Y                                  8921 non-null float64
# spCl                               3812 non-null object
# spSubCl                            2735 non-null object
# Var_Type                           8921 non-null object
# Var_subType                        256 non-null object
# Amplitude                          8921 non-null float64
# AndersonDarling                    8921 non-null float64
# Autocor_length                     8921 non-null float64
# Beyond1Std                         8921 non-null float64
# CAR_mean                           8921 non-null float64
# CAR_sigma                          8921 non-null float64
# CAR_tau                            8921 non-null float64
# Con                                8921 non-null float64
# Eta_e                              8921 non-null float64
# FluxPercentileRatioMid20           8921 non-null float64
# FluxPercentileRatioMid35           8921 non-null float64
# FluxPercentileRatioMid50           8921 non-null float64
# FluxPercentileRatioMid65           8921 non-null float64
# FluxPercentileRatioMid80           8921 non-null float64
# Freq1_harmonics_amplitude_0        8921 non-null float64
# Freq1_harmonics_amplitude_1        8921 non-null float64
# Freq1_harmonics_amplitude_2        8921 non-null float64
# Freq1_harmonics_amplitude_3        8921 non-null float64
# Freq1_harmonics_rel_phase_0        8921 non-null float64
# Freq1_harmonics_rel_phase_1        8921 non-null float64
# Freq1_harmonics_rel_phase_2        8921 non-null float64
# Freq1_harmonics_rel_phase_3        8921 non-null float64
# Freq2_harmonics_amplitude_0        8921 non-null float64
# Freq2_harmonics_amplitude_1        8921 non-null float64
# Freq2_harmonics_amplitude_2        8921 non-null float64
# Freq2_harmonics_amplitude_3        8921 non-null float64
# Freq2_harmonics_rel_phase_0        8921 non-null float64
# Freq2_harmonics_rel_phase_1        8921 non-null float64
# Freq2_harmonics_rel_phase_2        8921 non-null float64
# Freq2_harmonics_rel_phase_3        8921 non-null float64
# Freq3_harmonics_amplitude_0        8921 non-null float64
# Freq3_harmonics_amplitude_1        8921 non-null float64
# Freq3_harmonics_amplitude_2        8921 non-null float64
# Freq3_harmonics_amplitude_3        8921 non-null float64
# Freq3_harmonics_rel_phase_0        8921 non-null float64
# Freq3_harmonics_rel_phase_1        8921 non-null float64
# Freq3_harmonics_rel_phase_2        8921 non-null float64
# Freq3_harmonics_rel_phase_3        8921 non-null float64
# Gskew                              8921 non-null float64
# LinearTrend                        8921 non-null float64
# MaxSlope                           8921 non-null float64
# Mean                               8921 non-null float64
# Meanvariance                       8921 non-null float64
# MedianAbsDev                       8921 non-null float64
# MedianBRP                          8921 non-null float64
# PairSlopeTrend                     8921 non-null float64
# PercentAmplitude                   8921 non-null float64
# PercentDifferenceFluxPercentile    8921 non-null float64
# PeriodGLS                          8921 non-null float64
# PeriodLS                           8921 non-null float64
# PeriodWMCC                         8921 non-null float64
# Period_fit                         8921 non-null float64
# Psi_CS                             8921 non-null float64
# Psi_eta                            8921 non-null float64
# Q31                                8921 non-null float64
# Rcs                                8921 non-null float64
# Skew                               8921 non-null float64
# SlottedA_length                    8921 non-null float64
# SmallKurtosis                      8921 non-null float64
# Std                                8921 non-null float64
# StetsonK                           8921 non-null float64
# StetsonK_AC                        8921 non-null float64
# g-i                                2083 non-null float64
# g-r                                2540 non-null float64
# r-i                                2060 non-null float64
# dtypes: float64(69), object(5)
# memory usage: 5.1+ MB
# None
# /Users/jorgetil/miniconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/jorgetil/miniconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
label_samp.head()
# Out:
#                                           ID    raMedian  decMedian  \
# internalID
# Blind15A_35_N23_1408_3473  HiTS101111+012944  152.798620   1.495657
# Blind14A_19_N19_1720_3738  HiTS104506-002747  161.278461  -0.463066
# Blind14A_20_S9_1104_2980   HiTS104445+022013  161.189658   2.337103
# Blind14A_21_N5_0662_2268   HiTS105721+020221  164.337947   2.039295
# Blind14A_22_N6_0262_1631   HiTS105333-000140  163.390026  -0.027815
#
#                                      X            Y    spCl      spSubCl  \
# internalID
# Blind15A_35_N23_1408_3473  1408.947738  3473.264517  GALAXY          NaN
# Blind14A_19_N19_1720_3738  1720.768139  3738.788840  GALAXY    STARBURST
# Blind14A_20_S9_1104_2980   1104.247578  2980.433586  GALAXY          NaN
# Blind14A_21_N5_0662_2268    662.979512  2268.392342  GALAXY  STARFORMING
# Blind14A_22_N6_0262_1631    262.340695  1631.238769  GALAXY          NaN
#
#                           Var_Type Var_subType  Amplitude   ...          Rcs  \
# internalID                                                  ...
# Blind15A_35_N23_1408_3473      SNe         NaN   0.197745   ...     0.351900
# Blind14A_19_N19_1720_3738       NV         NaN   0.009567   ...     0.230762
# Blind14A_20_S9_1104_2980        NV         NaN   0.012085   ...     0.228233
# Blind14A_21_N5_0662_2268        NV         NaN   0.017333   ...     0.197445
# Blind14A_22_N6_0262_1631        NV         NaN   0.012767   ...     0.201758
#
#                                Skew  SlottedA_length  SmallKurtosis       Std  \
# internalID
# Blind15A_35_N23_1408_3473 -0.239747         0.269412       0.655449  0.102917
# Blind14A_19_N19_1720_3738 -0.035108         0.091238      -1.084781  0.006477
# Blind14A_20_S9_1104_2980   0.193119         0.091244      -0.700074  0.006947
# Blind14A_21_N5_0662_2268  -0.521790         0.091252       0.061091  0.009662
# Blind14A_22_N6_0262_1631   0.390108         0.091211       0.132114  0.006689
#
#                            StetsonK  StetsonK_AC       g-i       g-r      r-i
# internalID
# Blind15A_35_N23_1408_3473  0.776512     0.756380  1.984759  1.422029  0.56273
# Blind14A_19_N19_1720_3738  0.866802     0.685588       NaN       NaN      NaN
# Blind14A_20_S9_1104_2980   0.846997     0.767762       NaN       NaN      NaN
# Blind14A_21_N5_0662_2268   0.828883     0.747913       NaN       NaN      NaN
# Blind14A_22_N6_0262_1631   0.844004     0.775294       NaN       NaN      NaN
#
# [5 rows x 74 columns]
#                                           ID    raMedian  decMedian  \
# internalID
# Blind15A_35_N23_1408_3473  HiTS101111+012944  152.798620   1.495657
# Blind14A_19_N19_1720_3738  HiTS104506-002747  161.278461  -0.463066
# Blind14A_20_S9_1104_2980   HiTS104445+022013  161.189658   2.337103
# Blind14A_21_N5_0662_2268   HiTS105721+020221  164.337947   2.039295
# Blind14A_22_N6_0262_1631   HiTS105333-000140  163.390026  -0.027815
#
#                                      X            Y    spCl      spSubCl  \
# internalID
# Blind15A_35_N23_1408_3473  1408.947738  3473.264517  GALAXY          NaN
# Blind14A_19_N19_1720_3738  1720.768139  3738.788840  GALAXY    STARBURST
# Blind14A_20_S9_1104_2980   1104.247578  2980.433586  GALAXY          NaN
# Blind14A_21_N5_0662_2268    662.979512  2268.392342  GALAXY  STARFORMING
# Blind14A_22_N6_0262_1631    262.340695  1631.238769  GALAXY          NaN
#
#                           Var_Type Var_subType  Amplitude   ...          Rcs  \
# internalID                                                  ...
# Blind15A_35_N23_1408_3473      SNe         NaN   0.197745   ...     0.351900
# Blind14A_19_N19_1720_3738       NV         NaN   0.009567   ...     0.230762
# Blind14A_20_S9_1104_2980        NV         NaN   0.012085   ...     0.228233
# Blind14A_21_N5_0662_2268        NV         NaN   0.017333   ...     0.197445
# Blind14A_22_N6_0262_1631        NV         NaN   0.012767   ...     0.201758
#
#                                Skew  SlottedA_length  SmallKurtosis       Std  \
# internalID
# Blind15A_35_N23_1408_3473 -0.239747         0.269412       0.655449  0.102917
# Blind14A_19_N19_1720_3738 -0.035108         0.091238      -1.084781  0.006477
# Blind14A_20_S9_1104_2980   0.193119         0.091244      -0.700074  0.006947
# Blind14A_21_N5_0662_2268  -0.521790         0.091252       0.061091  0.009662
# Blind14A_22_N6_0262_1631   0.390108         0.091211       0.132114  0.006689
#
#                            StetsonK  StetsonK_AC       g-i       g-r      r-i
# internalID
# Blind15A_35_N23_1408_3473  0.776512     0.756380  1.984759  1.422029  0.56273
# Blind14A_19_N19_1720_3738  0.866802     0.685588       NaN       NaN      NaN
# Blind14A_20_S9_1104_2980   0.846997     0.767762       NaN       NaN      NaN
# Blind14A_21_N5_0662_2268   0.828883     0.747913       NaN       NaN      NaN
# Blind14A_22_N6_0262_1631   0.844004     0.775294       NaN       NaN      NaN
#
# [5 rows x 74 columns]

# %%
label_samp.Var_Type.value_counts()
# Out:
# NV        5000
# QSO       3495
# RRLYR      177
# EB         110
# CV          94
# SNe         29
# MISC         7
# ROTVAR       5
# ZZ           2
# DSCT         1
# LPV          1
# Name: Var_Type, dtype: int64
# NV        5000
# QSO       3495
# RRLYR      177
# EB         110
# CV          94
# SNe         29
# MISC         7
# ROTVAR       5
# ZZ           2
# DSCT         1
# LPV          1
# Name: Var_Type, dtype: int64

# %%
for label in set(label_samp.Var_Type):
    print label
    field = [f[:7] for f in label_samp.query('Var_Type == "%s"' % (label)).index]
    field = pd.Series(field)
    print field.value_counts()
    print '___________________________'
# Out:
# SNe
# Blind15    22
# Blind14     7
# dtype: int64
# ___________________________
# MISC
# Blind15    4
# Blind14    3
# dtype: int64
# ___________________________
# LPV
# Blind15    1
# dtype: int64
# ___________________________
# DSCT
# Blind15    1
# dtype: int64
# ___________________________
# QSO
# Blind15    2337
# Blind14    1158
# dtype: int64
# ___________________________
# EB
# Blind15    92
# Blind14    18
# dtype: int64
# ___________________________
# ROTVAR
# Blind15    5
# dtype: int64
# ___________________________
# ZZ
# Blind15    2
# dtype: int64
# ___________________________
# RRLYR
# Blind15    132
# Blind14     45
# dtype: int64
# ___________________________
# CV
# Blind15    64
# Blind14    30
# dtype: int64
# ___________________________
# NV
# Blind14    4996
# Blind15       4
# dtype: int64
# ___________________________
# SNe
# Blind15    22
# Blind14     7
# dtype: int64
# ___________________________
# MISC
# Blind15    4
# Blind14    3
# dtype: int64
# ___________________________
# LPV
# Blind15    1
# dtype: int64
# ___________________________
# DSCT
# Blind15    1
# dtype: int64
# ___________________________
# QSO
# Blind15    2337
# Blind14    1158
# dtype: int64
# ___________________________
# EB
# Blind15    92
# Blind14    18
# dtype: int64
# ___________________________
# ROTVAR
# Blind15    5
# dtype: int64
# ___________________________
# ZZ
# Blind15    2
# dtype: int64
# ___________________________
# RRLYR
# Blind15    132
# Blind14     45
# dtype: int64
# ___________________________
# CV
# Blind15    64
# Blind14    30
# dtype: int64
# ___________________________
# NV
# Blind14    4996
# Blind15       4
# dtype: int64
# ___________________________

# %%
print 'original shape:', label_samp.shape
cols = label_samp.columns.values
FATS_feats_all = cols[9:]
FATS_feats_gr = FATS_feats_all[(FATS_feats_all != 'g-i') & (FATS_feats_all != 'r-i')]
FATS_feats_non = cols[9:-3]
FATS_feats_non_mean = FATS_feats_non[(FATS_feats_non != 'Mean') & 
                                     (FATS_feats_non != 'CAR_mean') & 
                                     (FATS_feats_non != 'Meanvariance')]
print FATS_feats_non_mean

label_samp_all = label_samp.dropna(subset=FATS_feats_all)
label_samp_gr = label_samp.dropna(subset=FATS_feats_gr)
label_samp_non = label_samp.dropna(subset=FATS_feats_non)

print len(FATS_feats_all)
# Out:
# original shape: (8921, 74)
# ['Amplitude' 'AndersonDarling' 'Autocor_length' 'Beyond1Std' 'CAR_sigma'
#  'CAR_tau' 'Con' 'Eta_e' 'FluxPercentileRatioMid20'
#  'FluxPercentileRatioMid35' 'FluxPercentileRatioMid50'
#  'FluxPercentileRatioMid65' 'FluxPercentileRatioMid80'
#  'Freq1_harmonics_amplitude_0' 'Freq1_harmonics_amplitude_1'
#  'Freq1_harmonics_amplitude_2' 'Freq1_harmonics_amplitude_3'
#  'Freq1_harmonics_rel_phase_0' 'Freq1_harmonics_rel_phase_1'
#  'Freq1_harmonics_rel_phase_2' 'Freq1_harmonics_rel_phase_3'
#  'Freq2_harmonics_amplitude_0' 'Freq2_harmonics_amplitude_1'
#  'Freq2_harmonics_amplitude_2' 'Freq2_harmonics_amplitude_3'
#  'Freq2_harmonics_rel_phase_0' 'Freq2_harmonics_rel_phase_1'
#  'Freq2_harmonics_rel_phase_2' 'Freq2_harmonics_rel_phase_3'
#  'Freq3_harmonics_amplitude_0' 'Freq3_harmonics_amplitude_1'
#  'Freq3_harmonics_amplitude_2' 'Freq3_harmonics_amplitude_3'
#  'Freq3_harmonics_rel_phase_0' 'Freq3_harmonics_rel_phase_1'
#  'Freq3_harmonics_rel_phase_2' 'Freq3_harmonics_rel_phase_3' 'Gskew'
#  'LinearTrend' 'MaxSlope' 'MedianAbsDev' 'MedianBRP' 'PairSlopeTrend'
#  'PercentAmplitude' 'PercentDifferenceFluxPercentile' 'PeriodGLS'
#  'PeriodLS' 'PeriodWMCC' 'Period_fit' 'Psi_CS' 'Psi_eta' 'Q31' 'Rcs' 'Skew'
#  'SlottedA_length' 'SmallKurtosis' 'Std' 'StetsonK' 'StetsonK_AC']
# 65
# original shape: (8921, 74)
# ['Amplitude' 'AndersonDarling' 'Autocor_length' 'Beyond1Std' 'CAR_sigma'
#  'CAR_tau' 'Con' 'Eta_e' 'FluxPercentileRatioMid20'
#  'FluxPercentileRatioMid35' 'FluxPercentileRatioMid50'
#  'FluxPercentileRatioMid65' 'FluxPercentileRatioMid80'
#  'Freq1_harmonics_amplitude_0' 'Freq1_harmonics_amplitude_1'
#  'Freq1_harmonics_amplitude_2' 'Freq1_harmonics_amplitude_3'
#  'Freq1_harmonics_rel_phase_0' 'Freq1_harmonics_rel_phase_1'
#  'Freq1_harmonics_rel_phase_2' 'Freq1_harmonics_rel_phase_3'
#  'Freq2_harmonics_amplitude_0' 'Freq2_harmonics_amplitude_1'
#  'Freq2_harmonics_amplitude_2' 'Freq2_harmonics_amplitude_3'
#  'Freq2_harmonics_rel_phase_0' 'Freq2_harmonics_rel_phase_1'
#  'Freq2_harmonics_rel_phase_2' 'Freq2_harmonics_rel_phase_3'
#  'Freq3_harmonics_amplitude_0' 'Freq3_harmonics_amplitude_1'
#  'Freq3_harmonics_amplitude_2' 'Freq3_harmonics_amplitude_3'
#  'Freq3_harmonics_rel_phase_0' 'Freq3_harmonics_rel_phase_1'
#  'Freq3_harmonics_rel_phase_2' 'Freq3_harmonics_rel_phase_3' 'Gskew'
#  'LinearTrend' 'MaxSlope' 'MedianAbsDev' 'MedianBRP' 'PairSlopeTrend'
#  'PercentAmplitude' 'PercentDifferenceFluxPercentile' 'PeriodGLS'
#  'PeriodLS' 'PeriodWMCC' 'Period_fit' 'Psi_CS' 'Psi_eta' 'Q31' 'Rcs' 'Skew'
#  'SlottedA_length' 'SmallKurtosis' 'Std' 'StetsonK' 'StetsonK_AC']
# 65

# %%
print '#### TS without cleaning ####'
print label_samp.Var_Type.value_counts()
print '--------------------------------'
print '#### TS all colors ####'
print label_samp_all.Var_Type.value_counts()
print '--------------------------------'
print '#### TS with g-r ####'
print label_samp_gr.Var_Type.value_counts()
print '--------------------------------'
print '#### TS without colors ####'
print label_samp_non.Var_Type.value_counts()
# Out:
# #### TS without cleaning ####
# NV        5000
# QSO       3495
# RRLYR      177
# EB         110
# CV          94
# SNe         29
# MISC         7
# ROTVAR       5
# ZZ           2
# DSCT         1
# LPV          1
# Name: Var_Type, dtype: int64
# --------------------------------
# #### TS all colors ####
# QSO       1790
# RRLYR      115
# EB          74
# CV          49
# SNe         16
# ROTVAR       5
# MISC         4
# ZZ           1
# LPV          1
# NV           1
# Name: Var_Type, dtype: int64
# --------------------------------
# #### TS with g-r ####
# QSO       2220
# RRLYR      131
# EB          91
# CV          63
# SNe         19
# ROTVAR       5
# MISC         4
# NV           4
# ZZ           2
# LPV          1
# Name: Var_Type, dtype: int64
# --------------------------------
# #### TS without colors ####
# NV        5000
# QSO       3495
# RRLYR      177
# EB         110
# CV          94
# SNe         29
# MISC         7
# ROTVAR       5
# ZZ           2
# DSCT         1
# LPV          1
# Name: Var_Type, dtype: int64
# #### TS without cleaning ####
# NV        5000
# QSO       3495
# RRLYR      177
# EB         110
# CV          94
# SNe         29
# MISC         7
# ROTVAR       5
# ZZ           2
# DSCT         1
# LPV          1
# Name: Var_Type, dtype: int64
# --------------------------------
# #### TS all colors ####
# QSO       1790
# RRLYR      115
# EB          74
# CV          49
# SNe         16
# ROTVAR       5
# MISC         4
# ZZ           1
# LPV          1
# NV           1
# Name: Var_Type, dtype: int64
# --------------------------------
# #### TS with g-r ####
# QSO       2220
# RRLYR      131
# EB          91
# CV          63
# SNe         19
# ROTVAR       5
# MISC         4
# NV           4
# ZZ           2
# LPV          1
# Name: Var_Type, dtype: int64
# --------------------------------
# #### TS without colors ####
# NV        5000
# QSO       3495
# RRLYR      177
# EB         110
# CV          94
# SNe         29
# MISC         7
# ROTVAR       5
# ZZ           2
# DSCT         1
# LPV          1
# Name: Var_Type, dtype: int64

# %% [raw]
# label_samp_clean = label_samp_clean[label_samp_clean.Var_Type != 'DSCT']
# label_samp_clean = label_samp_clean[label_samp_clean.Var_Type != 'ZZ']
# label_samp_clean = label_samp_clean[label_samp_clean.Var_Type != 'LPV']
#
# train_sample, test_sample = model_selection.train_test_split(label_samp_clean,
#                                                               test_size=0.4, random_state=15,
#                                                              stratify=label_samp_clean['Var_Type'])
# print 'Shape of train set:', train_sample.shape
# print 'Shape of test set:', test_sample.shape

# %% [markdown]
# ### Feature selection from pyFmax

# %% [markdown]
# * pyFmax is a python package that di Feature selection based on feature contrasts

# %% [raw]
# from pyfmax import fmax
# from sklearn import preprocessing
#
# le = preprocessing.LabelEncoder()
# classes_enc = le.fit_transform(label_samp_clean_all['Var_Type'].values)
# print classes_enc
#
# obj = fmax.MatrixClustered(label_samp_clean_all[FATS_feats].values, classes_enc, labels_col=FATS_feats)
# feat_select = obj.get_features_selected()
# print feat_select
#
# for idx, list_features in enumerate(feat_select):
#     print "Feature selected for class ", le.inverse_transform(idx)
#     for f in list_features:
#         print '\t', obj.get_col_label(f)
#
# print "Features selected for the entire dataset:"
# fmax_feat_select = FATS_feats[list(obj.get_features_selected_flat())]
# print fmax_feat_select

# %%
def test_n_estimators(X, y, hiperparam='n_estimators', test_range=np.arange(0,100,10), plot=True):
    test_range[0] = 1
    if hiperparam == 'n_estimators':
        print "N estimators = ", test_range
    else:
        print "Max depth = ", test_range
    scores = np.zeros(len(test_range))
    stds = np.zeros(len(test_range))
    oob_error = np.zeros(len(test_range))
    
    for i in range(len(test_range)):
        N = test_range[i]
        if hiperparam == 'n_estimators':
            rf_clf = RandomForestClassifier(n_estimators=N, criterion='entropy',
                               max_features='sqrt', max_depth=10, n_jobs=2,
                                min_samples_leaf=1, oob_score=True,
                                class_weight='balanced_subsample')
        else:
            rf_clf = RandomForestClassifier(n_estimators=50, criterion='entropy',
                               max_features='sqrt', max_depth=N, n_jobs=2,
                                min_samples_leaf=1, oob_score=True,
                                class_weight='balanced_subsample')
        ss = model_selection.StratifiedKFold(n_splits=6, random_state=10)
        scores_i = model_selection.cross_val_score(rf_clf, X, y, cv=ss, n_jobs=3, verbose=1, 
                                                   scoring='f1')
        scores[i] = scores_i.mean()
        stds[i] = scores_i.std()
        rf_clf.fit(X, y)
        oob_error[i] = 1 - rf_clf.oob_score_
    
    if plot:
        fig, ax = plt.subplots(1,2,figsize=(14, 4))
        ax[0].plot(test_range, oob_error)
        ax[0].set_xlabel(hiperparam)
        ax[0].set_ylabel("OOB error rate")
        ax[0].grid()
        ax[1].errorbar (test_range, scores, yerr = stds)
        ax[1].set_xlabel(hiperparam)
        ax[1].set_ylabel("Accuracy")
        ax[1].grid()
        plt.show()

# %% [markdown]
# ## Bagging PU test - OneVsAll (Binary classification)

# %% [raw]
# for i,clas in enumerate(lb.classes_):
#     print clas
#     bagging_PU(label_samp_clean[FATS_feats].values, y_bin[:,i], known_labels_ratio=.5, K=150)
#     print '___________________________________'

# %% [markdown]
# ## Hierarchical approach

# %% [markdown]
# # Variable vs NonVariable

# %% [markdown]
# ## Without QSO

# %%
remove_sn = ['Blind15A_08_S29_0364_0480', 'Blind15A_15_N22_1632_3972',
             'Blind15A_26_N10_1235_2658', 'Blind15A_26_S23_1632_1684',
             'Blind15A_34_N1_0805_2093', 'Blind15A_35_N5_1843_2802',
             'Blind15A_38_N21_1524_3494', 'Blind15A_35_N23_1408_3473',
             'Blind15A_39_S10_0859_1758', 'Blind15A_45_N8_1698_3074',
             'Blind15A_46_S24_0879_0613', 'Blind15A_47_S27_0978_3515',
             'Blind14A_13_S2_0714_1701', 'Blind14A_21_S5_0868_2177',
             'Blind14A_24_N12_0134_1258', 'Blind14A_25_N4_1650_2829',
             'Blind14A_34_S17_1342_2536']
print len(remove_sn)
label_samp_non.drop(remove_sn, inplace=True)
# Out:
# 17
# 17

# %%
syn_nv = pd.read_csv('%s/tables/synthetics/Syntectic_NV_features_noise.csv' % mainpath)#.sample(1000)
#syn_nv['g-i'] = label_samp_all.sample(len(syn_nv), random_state=1)['g-i'].values
#syn_nv['g-r'] = label_samp_all.sample(len(syn_nv), random_state=2)['g-r'].values
#syn_nv['r-i'] = label_samp_all.sample(len(syn_nv), random_state=3)['r-i'].values

syn_dsct = pd.read_csv('%s/tables/synthetics/Syntectic_DSCT_features_noise.csv' % mainpath).sample(1000)
syn_rotv = pd.read_csv('%s/tables/synthetics/Syntectic_ROTVAR_features_noise.csv' % mainpath).sample(1000)
syn_rrly = pd.read_csv('%s/tables/synthetics/Syntectic_RRLYR_features_noise.csv' % mainpath).sample(1000)
syn_eb = pd.read_csv('%s/tables/synthetics/Syntectic_EB_features_noise.csv' % mainpath)

syn_rotv = syn_rotv.query('Period_fit < .1')
syn_dsct = syn_dsct.query('Period_fit < .1')
syn_rrly = syn_rrly.query('Period_fit < .1')
syn_eb = syn_eb.query('Period_fit < .02')
#syn_rrly2 = syn_rrly2.query('Period_fit < .3')
print syn_rrly.shape

label_samp_all_gpf = label_samp_non.query('(Var_Type == "RRLYR" or\
                                               Var_Type == "EB" or\
                                               Var_Type == "ROTVAR" or\
                                               Var_Type == "DSCT" or\
                                               Var_Type == "ZZ" or\
                                               Var_Type == "LPV") and\
                                               Period_fit < .5 or\
                                              (Var_Type != "RRLYR" and\
                                               Var_Type != "EB" and\
                                               Var_Type != "ROTVAR" and\
                                               Var_Type != "DSCT" and\
                                               Var_Type != "ZZ" and\
                                               Var_Type != "LPV")')
print 'gpf / all', label_samp_all_gpf.shape, label_samp_non.shape
#label_samp_all_gpf[cols].to_csv('%s/tables/HiTS_training_set_goodP.csv'\
#                        %(mainpath))
print label_samp_all_gpf.Var_Type.value_counts()

syn_sample = pd.concat([label_samp_all_gpf, syn_nv, syn_rotv, syn_dsct, syn_eb, syn_rrly], axis=0)
print syn_sample.Var_Type.value_counts()
#syn_sample[cols].to_csv('%s/tables/HiTS_training_set_full_DA_goodP.csv'\
#                        %(mainpath))
syn_sample_noqso = syn_sample.query('~(Var_Type == "QSO" or Var_Type == "CV")')
print syn_sample_noqso.Var_Type.value_counts()
# Out:
# (147, 64)
# gpf / all (8836, 74) (8904, 74)
# NV        5000
# QSO       3495
# RRLYR      134
# CV          94
# EB          87
# SNe         12
# MISC         7
# ROTVAR       5
# DSCT         1
# LPV          1
# Name: Var_Type, dtype: int64
# NV        9999
# QSO       3495
# EB         311
# RRLYR      281
# ROTVAR     175
# DSCT       166
# CV          94
# SNe         12
# MISC         7
# LPV          1
# Name: Var_Type, dtype: int64
# NV        9999
# EB         311
# RRLYR      281
# ROTVAR     175
# DSCT       166
# SNe         12
# MISC         7
# LPV          1
# Name: Var_Type, dtype: int64
# (147, 64)
# gpf / all (8836, 74) (8904, 74)
# NV        5000
# QSO       3495
# RRLYR      134
# CV          94
# EB          87
# SNe         12
# MISC         7
# ROTVAR       5
# DSCT         1
# LPV          1
# Name: Var_Type, dtype: int64
# NV        9999
# QSO       3495
# EB         311
# RRLYR      281
# ROTVAR     175
# DSCT       166
# CV          94
# SNe         12
# MISC         7
# LPV          1
# Name: Var_Type, dtype: int64
# NV        9999
# EB         311
# RRLYR      281
# ROTVAR     175
# DSCT       166
# SNe         12
# MISC         7
# LPV          1
# Name: Var_Type, dtype: int64

# %%
print syn_sample.query('Var_Type != "LPV" and Var_Type != "MISC"').shape
syn_sample.query('Var_Type != "LPV" and Var_Type != "MISC"').Var_Type.value_counts().plot(kind="bar")
plt.yscale('log')
# Out:
# (14533, 75)
# (14533, 75)

# %%
y_var = conv_into_binary_class(syn_sample_noqso['Var_Type'].values,
                             neg_bool=True, neg_label='NV')
print'Var/nonVar:',
print '%i/%i' % (y_var[y_var==1].shape[0],
                 y_var[y_var==0].shape[0])
# Out:
# Var/nonVar: 953/9999
# Var/nonVar: 953/9999

# %%
dummy_var = np.zeros_like(y_var)
mag_hist = np.histogram(syn_sample_noqso.Mean.values, bins='auto')[1]
mean_stds = []

for k in range(len(mag_hist)-1):
    mask = (syn_sample_noqso.Mean.values > mag_hist[k]) & (syn_sample_noqso.Mean.values <= mag_hist[k+1])
    mean_std = np.median(syn_sample_noqso.Std[mask])
    mean_stds.append(2. * mean_std)

for k in range(len(syn_sample_noqso)):
    #print syn_sample_noqso.iloc[k][['Mean','Std']]
    interp = np.interp(syn_sample_noqso.iloc[k]['Mean'], mag_hist[:-1], mean_stds)
    #print interp
    if syn_sample_noqso.iloc[k]['Std'] > interp:
        #print 'Variable!'
        dummy_var[k] = 1
    #print '_______'
    #break

# %%
print metrics.classification_report(y_var, dummy_var)
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      0.99      0.99      9999
#           1       0.92      0.97      0.95       953
#
# avg / total       0.99      0.99      0.99     10952
#
#              precision    recall  f1-score   support
#
#           0       1.00      0.99      0.99      9999
#           1       0.92      0.97      0.95       953
#
# avg / total       0.99      0.99      0.99     10952

# %%
plt.plot(syn_sample_noqso.Mean[y_var==1],
         syn_sample_noqso.Std[y_var==1], 'r.', ms=3)
plt.plot(syn_sample_noqso.Mean[dummy_var==1],
         syn_sample_noqso.Std[dummy_var==1], 'g.', ms=3)
plt.plot(syn_sample_noqso.Mean[y_var==0],
         syn_sample_noqso.Std[y_var==0], 'b.', ms=3)
plt.plot(mag_hist[:-1], mean_stds, 'k*-')
plt.show()

# %%
test_n_estimators(syn_sample_noqso[FATS_feats_non], y_var)
# Out:
# N estimators =  [ 1 10 20 30 40 50 60 70 80 90]
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    0.5s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.7s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    2.6s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    3.4s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    4.5s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    6.3s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    6.6s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    7.2s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    8.0s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    9.5s finished

# %%
test_n_estimators(syn_sample_noqso[FATS_feats_non], y_var,
                  hiperparam='max_depth', test_range=np.arange(0,20,2))
# Out:
# Max depth =  [ 1  2  4  6  8 10 12 14 16 18]
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    2.5s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    3.2s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    4.2s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    5.2s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    5.2s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    5.7s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    5.2s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    6.9s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    5.6s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    5.3s finished

# %%
from sklearn import cross_validation

# %%
RFC = RandomForestClassifier(n_estimators=30, criterion='gini',
                           max_features='sqrt', max_depth=8, n_jobs=2,
                            min_samples_leaf=10, oob_score=True,
                            class_weight='balanced_subsample')

#ss = cross_validation.StratifiedKFold(y_var, n_folds=6, random_state=10)

#scores = cross_validation.cross_val_score(RFC, syn_sample_noqso[FATS_feats_non],
#                                         y_var, scoring='f1', cv=6, n_jobs=-1, verbose=1)
predict_class_v = cross_validation.cross_val_predict(RFC, syn_sample_noqso[FATS_feats_non],
                                   y_var, cv=10, n_jobs=2, verbose=1)
#predict_proba_v = cross_validation.cross_val_predict(RFC, syn_sample_noqso[FATS_feats_non],
#                                   y_var, cv=10, n_jobs=2, verbose=1, method='predict_proba')

# %%
#print "F-1 = ", np.median(scores), "+-", mad(scores)
print metrics.classification_report(y_var, predict_class_v)
save_path = '%s/figures/conf_matrix_var_nonvar_RFC_orgTS.pdf' % (mainpath)
conf_matrix(true=y_var, predict=predict_class_v, classes=[0,1], save=False, normalized=True,
           class_names=['Nonvariable', 'Variable'])

#ROC_F1_thresh_curves_binary(y_var.ravel(), predict_proba_v[:, 1])

# %%
print len(FATS_feats_all)
RFC_varNonQSO_save = RandomForestClassifier(n_estimators=30, criterion='entropy',
                           max_features='sqrt', max_depth=8, n_jobs=2,
                            min_samples_leaf=1, oob_score=True,
                            class_weight='balanced_subsample')

RFC_varNonQSO_save.fit(syn_sample_noqso[FATS_feats_non], y_var)
joblib.dump(RFC_varNonQSO_save, '%s/models/RFC_variable_nonQSO_DA.pkl' % mainpath) 

feat_imp = pd.DataFrame(np.array([FATS_feats_non, RFC_varNonQSO_save.feature_importances_]).T,
                        columns=['feat_name','feat_score'])
feat_imp.sort_values('feat_score', ascending=False).head(10)
# Out:
# 65
#                           feat_name feat_score
# 51                       Period_fit   0.181256
# 53                          Psi_eta   0.141695
# 58                    SmallKurtosis  0.0999549
# 61                      StetsonK_AC   0.067086
# 41                             Mean  0.0571571
# 49                         PeriodLS  0.0509576
# 54                              Q31  0.0496111
# 42                     Meanvariance   0.049251
# 43                     MedianAbsDev  0.0469367
# 47  PercentDifferenceFluxPercentile  0.0419514

# %% [markdown]
# ## we clean contaminating QSO

# %% [raw]
# label_samp_all_copy = syn_sample.copy()
# print label_samp_all_copy.shape
# print predict_class_v.shape
# label_samp_all_copy['prediction'] = predict_class_v
# label_samp_all_qso_clean = label_samp_all_copy.query('~(Var_Type != "NV" and prediction == 0)')

# %% [raw]
# y_var = conv_into_binary_class(label_samp_all_qso_clean['Var_Type'].values,
#                              neg_bool=True, neg_label='NV')
# print'Var/nonVar:',
# print '%i/%i' % (y_var[y_var==1].shape[0],
#                  y_var[y_var==0].shape[0])
#
# RFC = RandomForestClassifier(n_estimators=50, criterion='gini',
#                            max_features='sqrt', max_depth=10, n_jobs=2,
#                             min_samples_leaf=1, oob_score=True,
#                             class_weight='balanced_subsample')
#
# ss = model_selection.StratifiedShuffleSplit(n_splits=10, train_size=2./3.,
#                                             random_state=10)
#
# scores = model_selection.cross_val_score(RFC, label_samp_all_qso_clean[FATS_feats_non],
#                                          y_var, scoring='accuracy', cv=ss, n_jobs=2, verbose=1)
# prediction = model_selection.cross_val_predict(RFC, label_samp_all_qso_clean[FATS_feats_non],
#                                    y_var, cv=10, n_jobs=2, verbose=1)

# %% [raw]
# print "Accuracy = ", scores.mean(), "+-", scores.std()
# print metrics.classification_report(y_var, prediction)
# save_path = '%s/figures/conf_matrix_var_nonvar_RFC_cleanQSO.pdf' % (mainpath)
# conf_matrix(true=y_var, predict=prediction, classes=[0,1], save=False, normalized=True,
#            class_names=['NonVariable', 'Variable'])

# %% [markdown]
# ## static QSO --> NV

# %% [raw]
# label_samp_all_qsoTOnv = syn_sample.copy()
# label_samp_all_qsoTOnv['prediction'] = predict_class_v
#
# idx = label_samp_all_qsoTOnv.query('(Var_Type != "NV" and prediction == 0)').index.values
# #print idx
# label_samp_all_qsoTOnv.loc[idx, 'Var_Type'] = 'NV'
# print label_samp_all_qsoTOnv.loc[idx,'Var_Type'].values
# print label_samp_all.loc[idx,'Var_Type'].values.shape
# y_var = conv_into_binary_class(label_samp_all_qsoTOnv['Var_Type'].values,
#                              neg_bool=True, neg_label='NV')

# %% [raw]
# test_n_estimators(label_samp_all_qsoTOnv[FATS_feats_all],y_var)

# %% [raw]
# test_n_estimators(label_samp_all_qsoTOnv[FATS_feats_all], y_var,
#                   hiperparam='max_depth', test_range=np.arange(0,20,2))

# %% [raw]
# print'Var/nonVar:',
# print '%i/%i' % (y_var[y_var==1].shape[0],
#                  y_var[y_var==0].shape[0])
#
# RFC = RandomForestClassifier(n_estimators=40, criterion='entropy',
#                            max_features='sqrt', max_depth=10, n_jobs=2,
#                             min_samples_leaf=1, oob_score=True,
#                             class_weight='balanced')
#
# ss = model_selection.StratifiedShuffleSplit(n_splits=10, train_size=2./3.,
#                                             random_state=10)
#
# scores = model_selection.cross_val_score(RFC, label_samp_all_qsoTOnv[FATS_feats_non],
#                                          y_var, scoring='accuracy', cv=ss, n_jobs=2, verbose=1)
# predict_prob = model_selection.cross_val_predict(RFC, label_samp_all_qsoTOnv[FATS_feats_non],
#                                    y_var, cv=10, n_jobs=2, verbose=1, method='predict_proba')
# predict_lab = [np.argmax(x) for x in predict_prob]

# %% [raw]
# print "Accuracy = ", scores.mean(), "+-", scores.std()
# print metrics.classification_report(y_var, predict_lab)
# save_path = '%s/figures/conf_matrix_var_nonvar_RFC_qsoTOnv.pdf' % (mainpath)
# conf_matrix(true=y_var, predict=predict_lab, classes=[0,1], save=save_path, normalized=True,
#            class_names=['NonVariable', 'Variable'])
# ROC_F1_thresh_curves_binary(y_var.ravel(), predict_prob[:, 1])

# %% [markdown]
# ## final model for variable/non--variables

# %% [raw]
# print len(FATS_feats_all)
# RFC_var_save = RandomForestClassifier(n_estimators=40, criterion='entropy',
#                            max_features='sqrt', max_depth=10, n_jobs=2,
#                             min_samples_leaf=1, oob_score=True,
#                             class_weight='balanced_subsample')
#
# RFC_var_save.fit(label_samp_all_qsoTOnv[FATS_feats_all],  y_var)
# joblib.dump(RFC_var_save, '%s/models/RFC_variable_DA.pkl' % mainpath)
#
# feat_imp = pd.DataFrame(np.array([FATS_feats_all, RFC_var_save.feature_importances_]).T,
#                         columns=['feat_name','feat_score'])
# feat_imp.sort_values('feat_score', ascending=False).head(10)

# %% [markdown]
# ### clasificar qso

# %%
qso_only = syn_sample.query('Var_Type == "QSO"')
print qso_only.shape

qso_pred = RFC_varNonQSO_save.predict_proba(qso_only[FATS_feats_non])
print len(qso_pred[qso_pred[:,1]>1/2.])
plt.hist(qso_pred[:,1], histtype='step', lw=1, color='b', bins=20, log=True)
plt.axvline(1/2., color='r')
plt.show()

var_qso = qso_only[qso_pred[:,1] >= 1/2.]
nvar_qso = qso_only[qso_pred[:,1] < 1/2.]
print var_qso.shape
# Out:
# (3495, 75)
# 177
# (177, 75)

# %%
plt.plot(nvar_qso.Mean, nvar_qso.Std, '.b')
plt.plot(var_qso.Mean, var_qso.Std, '.r')
plt.show()

# %% [markdown]
# ### Periodic vs NonPeriodic

# %%
label_samp_varonly = syn_sample.query('~(Var_Type == "QSO" or Var_Type == "NV")')
label_samp_varonly = pd.concat([label_samp_varonly, var_qso], axis=0)
print label_samp_varonly.shape
# Out:
# (1230, 75)

# %%
ts_nv = syn_sample.query('Var_Type == "NV"')
print ts_nv.shape
LS_to_save = pd.concat([label_samp_varonly_goodPF, ts_nv], axis=0)
print LS_to_save.shape
print LS_to_save.Var_Type.value_counts()
LS_to_save[cols].to_csv('%s/tables/HiTS_training_set_clean_DA.csv'\
                        %(mainpath))
# Out:
# (9999, 75)
# (11229, 75)
# NV        9999
# EB         311
# RRLYR      280
# ROTVAR     190
# QSO        177
# DSCT       158
# CV          94
# SNe         12
# MISC         7
# LPV          1
# Name: Var_Type, dtype: int64

# %%
# removing periodic items with bad period fit (Period_fit > .5)
label_samp_varonly_goodPF = label_samp_varonly.query('(Var_Type == "RRLYR" or\
                                               Var_Type == "EB" or\
                                               Var_Type == "ROTVAR" or\
                                               Var_Type == "DSCT" or\
                                               Var_Type == "ZZ" or\
                                               Var_Type == "LPV") and\
                                               Period_fit < .5 or\
                                              (Var_Type != "RRLYR" and\
                                               Var_Type != "EB" and\
                                               Var_Type != "ROTVAR" and\
                                               Var_Type != "DSCT" and\
                                               Var_Type != "ZZ" and\
                                               Var_Type != "LPV")')
print label_samp_varonly_goodPF.Var_Type.value_counts()
#plt.hist(label_samp_varonly_goodPF.Period_fit, bins=20)
#plt.show()
y_periodic = conv_into_binary_class(label_samp_varonly_goodPF['Var_Type'].values,
                             pos_label=['RRLYR','EB','ROTVAR','DSCT','ZZ','LPV'])
# Out:
# EB        311
# RRLYR     280
# ROTVAR    190
# QSO       177
# DSCT      158
# CV         94
# SNe        12
# MISC        7
# LPV         1
# Name: Var_Type, dtype: int64

# %%
test_n_estimators(label_samp_varonly_goodPF[FATS_feats_non], y_periodic)
# Out:
# N estimators =  [ 1 10 20 30 40 50 60 70 80 90]
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    0.3s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    0.7s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    0.8s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.1s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.2s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.4s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.5s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.8s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    2.0s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    2.3s finished

# %%
test_n_estimators(label_samp_varonly_goodPF[FATS_feats_non], y_periodic,
                  hiperparam='max_depth', test_range=np.arange(0,20,2))
# Out:
# Max depth =  [ 1  2  4  6  8 10 12 14 16 18]
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.3s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.4s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.4s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.5s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.4s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.4s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.4s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.4s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.5s finished
# [Parallel(n_jobs=3)]: Done   6 out of   6 | elapsed:    1.4s finished

# %%
print'Periodic/nonPeriodic:',
print '%i/%i' % (y_periodic[y_periodic==1].shape[0],
                 y_periodic[y_periodic==0].shape[0])

RFC = RandomForestClassifier(n_estimators=30, criterion='entropy',
                           max_features='sqrt', max_depth=6, n_jobs=2,
                            min_samples_leaf=1, oob_score=True,
                            class_weight='balanced_subsample')

scores = model_selection.cross_val_score(RFC, label_samp_varonly_goodPF[FATS_feats_non],
                                         y_periodic, scoring='f1', cv=ss, n_jobs=2, verbose=1)
predict_prob = model_selection.cross_val_predict(RFC, label_samp_varonly_goodPF[FATS_feats_non],
                                               y_periodic, cv=10, n_jobs=2, verbose=1, method='predict_proba')
predict_lab = [np.argmax(x) for x in predict_prob]
# Out:
# Periodic/nonPeriodic: 940/290
# [Parallel(n_jobs=2)]: Done   6 out of   6 | elapsed:    1.6s finished
# [Parallel(n_jobs=2)]: Done  10 out of  10 | elapsed:    2.6s finished

# %%
print scores
print "F-1 = ", np.mean(scores), "+-", mad(scores)
print metrics.classification_report(y_periodic, predict_lab)
save_path = '%s/figures/conf_matrix_per_nonper_RFC.pdf' % (mainpath)
conf_matrix(true=y_periodic, predict=predict_lab, classes=[0,1], save=save_path, normalized=True,
           class_names=['NonPeriodic', 'Periodic'])
ROC_F1_thresh_curves_binary(y_periodic.ravel(), predict_prob[:, 1])
# Out:
# [ 0.96732026  1.          0.99053628  1.          0.99047619  1.        ]
# F-1 =  0.991388788253 +- 0.00701546791091
#              precision    recall  f1-score   support
#
#           0       0.97      0.96      0.96       290
#           1       0.99      0.99      0.99       940
#
# avg / total       0.98      0.98      0.98      1230

# %%
RFC_per_save = RandomForestClassifier(n_estimators=30, criterion='entropy',
                           max_features='sqrt', max_depth=6, n_jobs=2,
                            min_samples_leaf=1, oob_score=True,
                            class_weight='balanced_subsample')

RFC_per_save.fit(label_samp_varonly_goodPF[FATS_feats_non], y_periodic)
joblib.dump(RFC_per_save, '%s/models/RFC_periodics_nonperiodic_DA.pkl' % mainpath) 
feat_imp = pd.DataFrame(np.array([FATS_feats_non, RFC_per_save.feature_importances_]).T,
                        columns=['feat_name','feat_score'])
feat_imp.sort_values('feat_score', ascending=False).head(10)
# Out:
#                       feat_name feat_score
# 51                   Period_fit   0.183745
# 5                     CAR_sigma   0.113275
# 14  Freq1_harmonics_amplitude_0  0.0869015
# 53                      Psi_eta  0.0860225
# 59                          Std  0.0784106
# 54                          Q31  0.0610829
# 42                 Meanvariance  0.0460566
# 6                       CAR_tau  0.0322108
# 49                     PeriodLS  0.0251392
# 58                SmallKurtosis  0.0206942

# %% [markdown]
# ### RotVar vs all periodic

# %% [raw]
# rotvar_vs_per = label_samp_clean_all.query('Var_Type != "NV"')
# print label_samp_clean_var_only.shape

# %% [markdown]
# ### Periodic subclasses

# %% [raw]
# label_samp_peronly_goodPF = label_samp_varonly_goodPF.query('Var_Type == "RRLYR" or \
#                                                              Var_Type == "EB" or \
#                                                              Var_Type == "ROTVAR"')
# print label_samp_peronly_goodPF.shape

# %% [raw]
# print label_samp_peronly_goodPF.Var_Type.value_counts()

# %% [raw]
# RFC = RandomForestClassifier(n_estimators=50, criterion='gini',
#                            max_features='sqrt', max_depth=4, n_jobs=2,
#                             min_samples_leaf=1, oob_score=False,
#                             class_weight='balanced')
#
# ss = model_selection.StratifiedShuffleSplit(n_splits=4, train_size=2./3.,
#                                             random_state=10)
#
# scores = model_selection.cross_val_score(RFC, label_samp_peronly_goodPF[FATS_feats_non],
#                                          label_samp_peronly_goodPF['Var_Type'],
#                                          scoring='f1_macro', cv=ss, n_jobs=2, verbose=1)
# clases = list(set(label_samp_peronly_goodPF['Var_Type']))
#
# prediction = model_selection.cross_val_predict(RFC, label_samp_peronly_goodPF[FATS_feats_non],
#                                    label_samp_peronly_goodPF['Var_Type'], cv=10, n_jobs=2, verbose=1)

# %% [raw]
# print "Accuracy = ", scores.mean(), "+-", scores.std()
# print metrics.classification_report(label_samp_peronly_goodPF['Var_Type'], prediction)
# conf_matrix(true=label_samp_peronly_goodPF['Var_Type'], predict=prediction,
#             classes=clases, save=False, normalized=True)

# %% [markdown]
# ## Periodic subclasses with data aumentation

# %% [raw]
# rr_eb = label_samp_varonly_goodPF.query('Var_Type == "RRLYR" or \
#                                          Var_Type == "EB"')
# rv_ds = label_samp_varonly_goodPF.query('Var_Type == "ROTVAR" or \
#                                          Var_Type == "DSCT"')
#
# train_dsct, test_dsct = model_selection.train_test_split(syn_dsct, test_size=0.5, random_state=15)
# train_rotv, test_rotv = model_selection.train_test_split(syn_rotv, test_size=0.5, random_state=15)
# # split RR lyrae and EBs into train/test
# train_sample, test_sample = model_selection.train_test_split(rr_eb, test_size=0.3, random_state=15,
#                                                              stratify=rr_eb['Var_Type'])
# #print train_dsct.sample(84, random_state=45)
#
# # create train sample with real RRL and EBs plus synthetic DSCT and ROTVAR
# train_sample = pd.concat([train_sample, train_dsct.sample(106, random_state=45),
#                                         train_rotv.sample(52, random_state=45)], axis=0)
#
# # create test sample with real objects for all classes
# test_true = pd.concat([test_sample, rv_ds], axis=0)
# # create test sample with real and synthetic objects for all classes
# test_synt = pd.concat([test_sample, rv_ds, test_dsct.sample(92, random_state=87),
#                       test_rotv.sample(49, random_state=983)], axis=0)
#
# # final train set
# train_final = pd.concat([train_sample, test_synt], axis=0)
#
# print '##### Train set #####'
# print train_sample.Var_Type.value_counts()
# print '__________________________'
# print '##### Test set with real labels #####'
# print test_true.Var_Type.value_counts()
# print '__________________________'
# print '##### Test set with real and synthetic labels #####'
# print test_synt.Var_Type.value_counts()
# print '__________________________'
# print '##### Train + test set with real and synthetic labels #####'
# print train_final.Var_Type.value_counts()

# %%
sub_periodic = label_samp_varonly_goodPF.query('Var_Type == "RRLYR" or Var_Type == "EB" or \
                                                Var_Type == "DSCT" or Var_Type == "ROTVAR"')

# %%
test_n_estimators(sub_periodic[FATS_feats_non], sub_periodic['Var_Type'])
# Out:
# N estimators =  [ 1 10 20 30 40 50 60 70 80 90]
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    0.7s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    1.7s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.0s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.4s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.2s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.4s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.8s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    3.3s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    3.5s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    4.1s finished

# %%
test_n_estimators(sub_periodic[FATS_feats_non], sub_periodic['Var_Type'],
                  hiperparam='max_depth', test_range=np.arange(0,20,2))
# Out:
# Max depth =  [ 1  2  4  6  8 10 12 14 16 18]
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.1s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.2s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.2s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.4s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.4s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.5s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.5s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.5s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.5s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.5s finished

# %%
RFC = RandomForestClassifier(n_estimators=40, criterion='entropy',
                           max_features='sqrt', max_depth=10, n_jobs=2,
                            min_samples_leaf=1, oob_score=False,
                            class_weight='balanced')

scores = model_selection.cross_val_score(RFC, sub_periodic[FATS_feats_non], sub_periodic['Var_Type'], 
                                         scoring='f1_macro', cv=ss, n_jobs=2, verbose=1)
clases = list(set(sub_periodic['Var_Type']))

pred_y = model_selection.cross_val_predict(RFC, sub_periodic[FATS_feats_non],
                                               sub_periodic['Var_Type'], cv=10, n_jobs=2, verbose=1)
pred_prob = model_selection.cross_val_predict(RFC, sub_periodic[FATS_feats_non],
                                               sub_periodic['Var_Type'], method='predict_proba',
                                              cv=10, n_jobs=2,verbose=1)
# Out:
# [Parallel(n_jobs=2)]: Done   6 out of   6 | elapsed:    1.8s finished
# [Parallel(n_jobs=2)]: Done  10 out of  10 | elapsed:    2.4s finished
# [Parallel(n_jobs=2)]: Done  10 out of  10 | elapsed:    2.7s finished

# %%
print "F1 = ", np.median(scores), "+-", mad(scores)
print metrics.classification_report(sub_periodic['Var_Type'], pred_y)

save_path = '%s/figures/conf_matrix_per_subcls_RFC.pdf' % (mainpath)
conf_matrix(true=sub_periodic['Var_Type'], predict=pred_y, 
            classes=clases, save=save_path, normalized=True)
ROC_F1_thresh_curves_multiclass(pred_y, y_score=pred_prob, classes=clases)
# Out:
# F1 =  0.865576862041 +- 0.0423216328629
#              precision    recall  f1-score   support
#
#        DSCT       0.94      0.93      0.94       158
#          EB       0.80      0.89      0.84       311
#      ROTVAR       0.83      0.81      0.82       190
#       RRLYR       0.90      0.81      0.85       280
#
# avg / total       0.86      0.86      0.86       939

# %%
RFC_subper_save = RandomForestClassifier(n_estimators=40, criterion='entropy',
                           max_features='sqrt', max_depth=10, n_jobs=2,
                            min_samples_leaf=1, oob_score=True,
                            class_weight='balanced_subsample')

RFC_subper_save.fit(sub_periodic[FATS_feats_non], sub_periodic['Var_Type'])
joblib.dump(RFC_subper_save, '%s/models/RFC_periodics_subclasses_DA.pkl' % mainpath) 
feat_imp = pd.DataFrame(np.array([FATS_feats_non, RFC_subper_save.feature_importances_]).T,
                        columns=['feat_name','feat_score'])
feat_imp.sort_values('feat_score', ascending=False).head(10)
# Out:
#                           feat_name feat_score
# 4                          CAR_mean  0.0991702
# 49                         PeriodLS  0.0855584
# 6                           CAR_tau  0.0802947
# 42                     Meanvariance  0.0638981
# 38                            Gskew  0.0628017
# 5                         CAR_sigma  0.0565246
# 48                        PeriodGLS  0.0494001
# 56                             Skew  0.0483305
# 40                         MaxSlope  0.0480206
# 47  PercentDifferenceFluxPercentile  0.0373815

# %% [markdown]
# ### NonPeriodic subclasses

# %%
label_samp_varonly_nonP = label_samp_varonly.query('Var_Type == "QSO" or \
                                                    Var_Type == "CV" or \
                                                    Var_Type == "SNe"')
print label_samp_varonly_nonP.Var_Type.value_counts()
# Out:
# QSO    177
# CV      94
# SNe     12
# Name: Var_Type, dtype: int64

# %%
label_samp_varonly_nonP.dropna(subset=FATS_feats_all).Var_Type.value_counts()
# Out:
# QSO    102
# CV      49
# SNe      8
# Name: Var_Type, dtype: int64

# %%
test_n_estimators(label_samp_varonly_nonP[FATS_feats_non],
                                         label_samp_varonly_nonP['Var_Type'])
# Out:
# N estimators =  [ 1 10 20 30 40 50 60 70 80 90]
# [Parallel(n_jobs=3)]: Done   5 out of  10 | elapsed:    0.3s remaining:    0.3s
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    0.6s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    1.3s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    1.3s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    1.6s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    1.7s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.1s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.3s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.5s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.7s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    3.1s finished

# %%
test_n_estimators(label_samp_varonly_nonP[FATS_feats_non], label_samp_varonly_nonP['Var_Type'],
                  hiperparam='max_depth', test_range=np.arange(0,20,2))
# Out:
# Max depth =  [ 1  2  4  6  8 10 12 14 16 18]
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.1s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.0s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.6s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.3s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.1s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.1s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.0s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.1s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.1s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    2.0s finished

# %%
RFC = RandomForestClassifier(n_estimators=20, criterion='entropy',
                           max_features='sqrt', max_depth=8, n_jobs=2,
                            min_samples_leaf=1, oob_score=True,
                            class_weight='balanced_subsample')

ss = model_selection.StratifiedKFold(n_splits=6, random_state=10)

scores = model_selection.cross_val_score(RFC, label_samp_varonly_nonP[FATS_feats_non],
                                         label_samp_varonly_nonP['Var_Type'], 
                                         scoring='accuracy', cv=ss, n_jobs=2, verbose=1)
clases = list(set(label_samp_varonly_nonP['Var_Type']))
prediction = model_selection.cross_val_predict(RFC, label_samp_varonly_nonP[FATS_feats_non],
                                   label_samp_varonly_nonP['Var_Type'], cv=10, n_jobs=2,
                                                 verbose=1, method='predict')
# Out:
# [Parallel(n_jobs=2)]: Done   6 out of   6 | elapsed:    1.1s finished
# [Parallel(n_jobs=2)]: Done  10 out of  10 | elapsed:    1.7s finished

# %%
print "Accuracy = ", scores.mean(), "+-", scores.std()
print metrics.classification_report(label_samp_varonly_nonP['Var_Type'], prediction)
save_path = '%s/figures/conf_matrix_nonper_subclasses.pdf' % (mainpath)
conf_matrix(true=label_samp_varonly_nonP['Var_Type'], predict=prediction, 
            classes=clases, save=save_path, normalized=True)
# Out:
# Accuracy =  0.847919236304 +- 0.0453110146681
#              precision    recall  f1-score   support
#
#          CV       0.86      0.72      0.79        94
#         QSO       0.85      0.93      0.89       177
#         SNe       0.80      0.67      0.73        12
#
# avg / total       0.85      0.85      0.85       283

# %%
RFC_subNONper_save = RandomForestClassifier(n_estimators=10, criterion='entropy',
                           max_features='sqrt', max_depth=8, n_jobs=2,
                            min_samples_leaf=1, oob_score=True,
                            class_weight='balanced_subsample')

RFC_subNONper_save.fit(label_samp_varonly_nonP[FATS_feats_non], label_samp_varonly_nonP['Var_Type'])
joblib.dump(RFC_subNONper_save, '%s/models/RFC_nonperiodics_subclasses.pkl' % mainpath) 
feat_imp = pd.DataFrame(np.array([FATS_feats_non, RFC_subNONper_save.feature_importances_]).T,
                        columns=['feat_name','feat_score'])
feat_imp.sort_values('feat_score', ascending=False).head(10)
# Out:
#                           feat_name feat_score
# 2                    Autocor_length   0.136678
# 39                      LinearTrend   0.113568
# 54                              Q31   0.108056
# 59                              Std  0.0715266
# 15      Freq1_harmonics_amplitude_1  0.0641056
# 55                              Rcs  0.0598059
# 49                         PeriodLS  0.0537019
# 43                     MedianAbsDev  0.0413665
# 47  PercentDifferenceFluxPercentile   0.035938
# 48                        PeriodGLS  0.0344434

# %% [markdown]
# # Final Classifier

# %%
final_test_sample = tree_test.copy().query('~(Var_Type == "ZZ" or Var_Type == "LPV")')
final_test_sample = pd.concat([final_test_sample, test_synt], axis=0).dropna(subset=FATS_feats_all)
print final_test_sample.Var_Type.value_counts()
# Out:
# QSO       612
# RRLYR      74
# NV         51
# EB         49
# CV         24
# ROTVAR      6
# MISC        3
# DSCT        1
# SNe         1
# Name: Var_Type, dtype: int64

# %%
var_pred = RFC_var.predict(final_test_sample[FATS_feats_all])
variables = final_test_sample[var_pred == 1]
non_variables = final_test_sample[var_pred == 0]
non_variables['Prediction'] = 'NV'
# Out:
# /Users/jorgetil/miniconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
periodic_pred = RFC_per.predict(variables[FATS_feats_all])
periodic = variables[periodic_pred == 1]
non_periodic = variables[periodic_pred == 0]

# %%
subper_pred = RFC_subper.predict(periodic[FATS_feats_non])
periodic['Prediction'] = subper_pred
# Out:
# /Users/jorgetil/miniconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
subNper_pred = RFC_subnonP.predict(non_periodic[FATS_feats_all])
non_periodic['Prediction'] = subNper_pred
# Out:
# /Users/jorgetil/miniconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
final_predictions = pd.concat([non_variables, periodic, non_periodic], axis=0)
final_predictions[['Var_Type', 'Prediction']].head(10)
classes = np.unique(final_predictions.Var_Type.values)

# %%
print metrics.classification_report(final_predictions['Var_Type'], final_predictions['Prediction'])

print 'Macro-Precision score:',
print metrics.precision_score(final_predictions['Var_Type'], final_predictions['Prediction'], average='macro')
print 'Accuracy score:',
print metrics.accuracy_score(final_predictions['Var_Type'], final_predictions['Prediction'])

save_path = '%s/figures/conf_matrix_treeTest_RFC.pdf' % (mainpath)
conf_matrix(true=final_predictions['Var_Type'], predict=final_predictions['Prediction'], 
            classes=classes, save=save_path, normalized=True)
# Out:
#              precision    recall  f1-score   support
#
#          CV       0.06      0.29      0.10        24
#        DSCT       0.00      0.00      0.00         1
#          EB       0.87      0.82      0.84        49
#        MISC       0.00      0.00      0.00         3
#          NV       0.69      0.98      0.81        51
#         QSO       0.95      0.78      0.86       612
#      ROTVAR       0.20      0.50      0.29         6
#       RRLYR       0.98      0.82      0.90        74
#         SNe       0.00      0.00      0.00         1
#
# avg / total       0.89      0.78      0.83       821
#
# Macro-Precision score: 0.417049969013
# Accuracy score: 0.780755176614

# %% [markdown]
# ## Multiclass RF after all the cleaning

# %% [markdown]
# ### How meny estimators?

# %%
test_n_estimators(syn_sample[FATS_feats_non], syn_sample['Var_Type'])
# Out:
# N estimators =  [ 1 10 20 30 40 50 60 70 80 90]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-7523485f2f77> in <module>()
# ----> 1 test_n_estimators(syn_sample[FATS_feats_non], syn_sample['Var_Type'])
#
# <ipython-input-9-8704329a73fd> in test_n_estimators(X, y, hiperparam, test_range, plot)
#      24                                                 random_state=10)
#      25         scores_i = model_selection.cross_val_score(rf_clf, X, y, cv=ss, n_jobs=3, verbose=1,
# ---> 26                                                    scoring='accuracy')
#      27         scores[i] = scores_i.mean()
#      28         stds[i] = scores_i.std()
#
# /Users/jorgetil/miniconda2/lib/python2.7/site-packages/sklearn/model_selection/_validation.pyc in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     138                                               train, test, verbose, None,
#     139                                               fit_params)
# --> 140                       for train, test in cv.split(X, y, groups))
#     141     return np.array(scores)[:, 0]
#     142
#
# /Users/jorgetil/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# /Users/jorgetil/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     601
#     602         with self._lock:
# --> 603             tasks = BatchedCalls(itertools.islice(iterator, batch_size))
#     604             if len(tasks) == 0:
#     605                 # No more tasks available in the iterator: tell caller to stop.
#
# /Users/jorgetil/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __init__(self, iterator_slice)
#     125
#     126     def __init__(self, iterator_slice):
# --> 127         self.items = list(iterator_slice)
#     128         self._size = len(self.items)
#     129
#
# /Users/jorgetil/miniconda2/lib/python2.7/site-packages/sklearn/model_selection/_validation.pyc in <genexpr>(***failed resolving arguments***)
#     135     parallel = Parallel(n_jobs=n_jobs, verbose=verbose,
#     136                         pre_dispatch=pre_dispatch)
# --> 137     scores = parallel(delayed(_fit_and_score)(clone(estimator), X, y, scorer,
#     138                                               train, test, verbose, None,
#     139                                               fit_params)
#
# /Users/jorgetil/miniconda2/lib/python2.7/site-packages/sklearn/model_selection/_split.pyc in split(self, X, y, groups)
#     931         """
#     932         X, y, groups = indexable(X, y, groups)
# --> 933         for train, test in self._iter_indices(X, y, groups):
#     934             yield train, test
#     935
#
# /Users/jorgetil/miniconda2/lib/python2.7/site-packages/sklearn/model_selection/_split.pyc in _iter_indices(self, X, y, groups)
#    1235         class_counts = bincount(y_indices)
#    1236         if np.min(class_counts) < 2:
# -> 1237             raise ValueError("The least populated class in y has only 1"
#    1238                              " member, which is too few. The minimum"
#    1239                              " number of groups for any class cannot"
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.

# %% [markdown]
# ### tree depth

# %%
test_n_estimators(syn_sample[FATS_feats_non], syn_sample['Var_Type'],
                  hiperparam='max_depth', test_range=np.arange(0,20,2))
# Out:
# Max depth =  [ 1  2  4  6  8 10 12 14 16 18]
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    7.2s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    6.8s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:   10.0s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:   14.9s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:   14.6s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:   15.6s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:   16.2s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:   16.4s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:   16.9s finished
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:   16.5s finished

# %% [markdown]
# ### grid search

# %%
# split data with Stratified Shuffle Split
ss = model_selection.StratifiedShuffleSplit(n_splits=10, train_size=2./3.,
                                            random_state=10)
# Grid of params for RF
param_grid = {"max_depth": [10],
              "max_features": ['sqrt','log2'],
              "min_samples_split": [2,4,8],
              "min_samples_leaf": [1,3,5],
              "bootstrap": [True],
              "criterion": ["gini", "entropy"],
              "n_estimators": [40],
              "class_weight": ['balanced_subsample', 'balanced']}

# initialize RFC
rf_clf = RandomForestClassifier()
# initialize grid search
grid_search = model_selection.GridSearchCV(rf_clf, param_grid=param_grid, cv=ss,
                           n_jobs=4, verbose=1)
# fit data
grid_search.fit(syn_sample[FATS_feats_non], syn_sample['Var_Type'])

print "The best classifier is: ", grid_search.best_estimator_
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:   38.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=4)]: Done 720 out of 720 | elapsed: 10.2min finished
# The best classifier is:  RandomForestClassifier(bootstrap=True, class_weight='balanced_subsample',
#             criterion='entropy', max_depth=10, max_features='sqrt',
#             max_leaf_nodes=None, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=4,
#             min_weight_fraction_leaf=0.0, n_estimators=40, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# ## final multi--class RFC

# %%
syn_sample = syn_sample.query('~(Var_Type == "LPV" or Var_Type == "MISC")')
syn_sample.Var_Type.value_counts()
# Out:
# NV        5145
# QSO       2304
# ROTVAR    1076
# RRLYR      848
# DSCT       834
# EB         109
# CV          64
# SNe         10
# Name: Var_Type, dtype: int64

# %%
RFC_multi = RandomForestClassifier(bootstrap=True, class_weight='balanced_subsample',
            criterion='entropy', max_depth=10, max_features='sqrt',
            max_leaf_nodes=None, min_impurity_split=1e-07,
            min_samples_leaf=1, min_samples_split=4,
            min_weight_fraction_leaf=0.0, n_estimators=40, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)

ss = model_selection.StratifiedShuffleSplit(n_splits=10, train_size=2./3.,
                                            random_state=10)

scores = model_selection.cross_val_score(RFC_multi, syn_sample[FATS_feats_non_mean],
                                         syn_sample['Var_Type'], 
                                         scoring='f1_weighted', cv=ss, n_jobs=2, verbose=1)
print "Accuracy = ", scores.mean(), "+-", scores.std()
# Out:
# /Users/jorgetil/miniconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/jorgetil/miniconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy =  0.922335861608 +- 0.00393504628212
# [Parallel(n_jobs=2)]: Done  10 out of  10 | elapsed:   15.5s finished

# %%
clases = list(set(syn_sample['Var_Type']))
predicted_proba = model_selection.cross_val_predict(RFC_multi, syn_sample[FATS_feats_non_mean],
                                   syn_sample['Var_Type'],
                                    cv=10, n_jobs=2, verbose=1, method='predict_proba')
predicted_class = model_selection.cross_val_predict(RFC_multi, syn_sample[FATS_feats_non_mean],
                                   syn_sample['Var_Type'],
                                    cv=10, n_jobs=2, verbose=1, method='predict')
# Out:
# [Parallel(n_jobs=2)]: Done  10 out of  10 | elapsed:   20.0s finished
# [Parallel(n_jobs=2)]: Done  10 out of  10 | elapsed:   21.4s finished

# %%
print "Accuracy = ", scores.mean(), "+-", scores.std()
print metrics.classification_report(syn_sample['Var_Type'], predicted_class)

save_path = '%s/figures/conf_matrix_multiclassTest_cleanTS_DAall_RFC_qsodrop.pdf' % (mainpath)
conf_matrix(true=syn_sample['Var_Type'].values, predict=predicted_class, 
            classes=clases, save=save_path, normalized=True)

#PR_ROC_curves_multiclass(predicted_class, predicted_proba, clases)
# Out:
# Accuracy =  0.922335861608 +- 0.00393504628212
#              precision    recall  f1-score   support
#
#          CV       0.00      0.00      0.00        64
#        DSCT       0.94      0.96      0.95       834
#          EB       0.82      0.83      0.83       109
#          NV       0.98      0.91      0.94      5145
#         QSO       0.81      0.94      0.87      2304
#      ROTVAR       0.91      0.94      0.93      1076
#       RRLYR       0.92      0.86      0.89       848
#         SNe       1.00      0.30      0.46        10
#
# avg / total       0.92      0.92      0.91     10390

# %%
importance = []
for k in range(10):
    RFC_multi = RandomForestClassifier(bootstrap=True, class_weight='balanced_subsample',
            criterion='entropy', max_depth=10, max_features='sqrt',
            max_leaf_nodes=None, min_impurity_split=1e-07,
            min_samples_leaf=1, min_samples_split=4,
            min_weight_fraction_leaf=0.0, n_estimators=40, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)

    RFC_multi.fit(syn_sample[FATS_feats_non], syn_sample['Var_Type'])
    importance.append(RFC_multi.feature_importances_)

joblib.dump(RFC_multi, '%s/models/RFC_all_multiclass_DAall_balancedclassweight.pkl' % mainpath)
# Out:
# ['/Users/jorgetil/Astro/HITS/models/RFC_all_multiclass_DAall_balancedclassweight.pkl']

# %%
importance = np.array(importance)
feat_imp = pd.DataFrame(np.array([FATS_feats_non, importance.mean(axis=0)]).T,
                        columns=['feat_name','feat_score'])
feat_imp.sort_values('feat_score', ascending=False).head(10)
# Out:
#                       feat_name feat_score
# 51                   Period_fit  0.0987746
# 53                      Psi_eta  0.0718568
# 5                     CAR_sigma  0.0703048
# 6                       CAR_tau  0.0542508
# 49                     PeriodLS  0.0500849
# 4                      CAR_mean  0.0400192
# 57              SlottedA_length  0.0365239
# 14  Freq1_harmonics_amplitude_0  0.0362782
# 61                  StetsonK_AC  0.0325686
# 41                         Mean  0.0318852

# %%
FATS_feats_non_mean = FATS_feats_non[(FATS_feats_non != 'Mean') & 
                                     (FATS_feats_non != 'CAR_mean') & 
                                     (FATS_feats_non != 'Meanvariance') &
                                     (FATS_feats_non != 'Q31')]
print FATS_feats_non_mean
# Out:
# ['Amplitude' 'AndersonDarling' 'Autocor_length' 'Beyond1Std' 'CAR_sigma'
#  'CAR_tau' 'Con' 'Eta_e' 'FluxPercentileRatioMid20'
#  'FluxPercentileRatioMid35' 'FluxPercentileRatioMid50'
#  'FluxPercentileRatioMid65' 'FluxPercentileRatioMid80'
#  'Freq1_harmonics_amplitude_0' 'Freq1_harmonics_amplitude_1'
#  'Freq1_harmonics_amplitude_2' 'Freq1_harmonics_amplitude_3'
#  'Freq1_harmonics_rel_phase_0' 'Freq1_harmonics_rel_phase_1'
#  'Freq1_harmonics_rel_phase_2' 'Freq1_harmonics_rel_phase_3'
#  'Freq2_harmonics_amplitude_0' 'Freq2_harmonics_amplitude_1'
#  'Freq2_harmonics_amplitude_2' 'Freq2_harmonics_amplitude_3'
#  'Freq2_harmonics_rel_phase_0' 'Freq2_harmonics_rel_phase_1'
#  'Freq2_harmonics_rel_phase_2' 'Freq2_harmonics_rel_phase_3'
#  'Freq3_harmonics_amplitude_0' 'Freq3_harmonics_amplitude_1'
#  'Freq3_harmonics_amplitude_2' 'Freq3_harmonics_amplitude_3'
#  'Freq3_harmonics_rel_phase_0' 'Freq3_harmonics_rel_phase_1'
#  'Freq3_harmonics_rel_phase_2' 'Freq3_harmonics_rel_phase_3' 'Gskew'
#  'LinearTrend' 'MaxSlope' 'MedianAbsDev' 'MedianBRP' 'PairSlopeTrend'
#  'PercentAmplitude' 'PercentDifferenceFluxPercentile' 'PeriodGLS'
#  'PeriodLS' 'PeriodWMCC' 'Period_fit' 'Psi_CS' 'Psi_eta' 'Rcs' 'Skew'
#  'SlottedA_length' 'SmallKurtosis' 'Std' 'StetsonK' 'StetsonK_AC']

# %%
RFC_multi.n_features_
# Out:
# 59

# %%
importance = np.array(importance)
print importance.mean(axis=0).shape
# Out:
# (60,)
